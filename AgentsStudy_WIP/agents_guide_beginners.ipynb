# %% [markdown]
# AI agents for beginners: https://www.youtube.com/watch?v=OhI005_aJkA&list=PLlrxD0HtieHgKcRjd5-8DT9TbwdlDO-OC

# %% [markdown]
# "An agent is not simply an AI model in a static
# workflow; it's a complete application, making plans and taking actions to achieve goals. It
# combines a Language Model's (LM) ability to reason with the practical ability to act"
# - https://www.kaggle.com/whitepaper-introduction-to-agents

# %% [markdown]
# # Lesson 1: Components of an AI Agent
#
# ## 1. LLM (Large Language Model) — The Brain
#
# * Provides the **reasoning** behind the AI agent.
# * Identifies the task and the steps needed to complete it.
# * Performs or guides the execution of those steps.
#
# The model type (general-purpose, fine-tuned, or multimodal) dictates the agent's cognitive capabilities. An agentic system determines the LLM's input context window.
#
# ### 1.1 Memory
#
# * **Short-term:** Maintains context during the current conversation.
# * **Long-term:** Stores knowledge and experiences over time to improve performance.
#
# ## 2. Tools — The Hands
#
# * APIs, services, or functions the agent can access.
# * Provide data or capabilities to help determine and execute actions.
#
# An agentic system lets the LLM plan which tools to use, executes them, and feeds the results into the next LLM call's context window.
#
# ## 3. Orchestration Layer — The Nervous System
#
# Ties all components together. Handles planning, memory (state), and reasoning strategy execution — using frameworks like Chain-of-Thought or ReAct to break down goals into steps and decide when to think versus act.
#
# ## 4. Deployment — The Body and Legs
#
# Hosting the agent on a secure, scalable server, integrated with production services for monitoring, logging, and management. Once deployed, users can access the agent via a graphical interface, or other agents can access it programmatically via an Agent-to-Agent (A2A) API.
#
# ---
#
# **→ The AI agent uses these components to perform tasks efficiently. The agent developer, by contrast, is more like a director:**
#
# Instead of writing explicit code for every action, you set the scene (guiding instructions and prompts), select the cast (tools and APIs), and provide context (the data) — guiding this autonomous "actor" to deliver the intended performance.
#
#
# Through traces and logs, you can monitor the agent's "thought process" to identify deviations from the intended
# execution path.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lesson 2: Agentic Frameworks
#
# * **Purpose:** Tools that help manage and control tasks effectively.
# * **Multi-Agent Support:** Some tasks require multiple agents, and frameworks allow us to coordinate them.
# * **Resource Management:** Frameworks help keep track of the state of resources across agents.
# * **Agent Collaboration:** They define how agents work together to complete tasks, supporting multiple protocols and workflows.
# * **Examples of Frameworks:**
#
#   * **Azure AI:** Designed for single-agent setups.
#   * **Semantic Kernel:** Enterprise-focused framework.
#   * **AutoGen:** Research-oriented; can integrate with Azure and GitHub agents.

# %% [markdown]
# # Lesson 3: What Makes a Good AI Agent?
#
# 1. **Space**:
#    The environment in which the agent operates, connecting events, people, and knowledge. It should be easily discoverable and allow smooth transitions between foreground and background activities. Achievable through a well-designed UI that clearly explains the agent’s capabilities, usage instructions, and limitations.
#
# 2. **Time**:
#    How the agent interacts with the user over time. A good agent can improve through repeated interactions if designed properly, for example, by leveraging long-term memory.
#
# 3. **Core**:
#    Embracing uncertainty and enabling trust and transparency. This can be achieved by providing users with diverse controls and clear access to the agent’s decision-making process.

# %% [markdown]
# # Lesson 4: Agent Tool Use Design Pattern
#
# **Agentic Design Patterns** are architectural and behavioral templates that guide the development of AI systems. They define how agents interact with **tools, environments, and sometimes each other**, enabling scalable, modular, and adaptable designs.
#
# Key principles for agent design include:
#
# * **Efficiency** – minimize latency and maximize throughput.
# * **Robustness** – resilience to system failures.
# * **Scalability** – handle an increasing number of tasks effectively.
#
# ## Common Agentic Design Patterns
#
# 1. **Reflection Pattern**
#
#    * Agents introspect and evaluate their actions or decisions for iterative improvement.
#    * **Design Flow:** Perform action → collect results → compare against predefined goals → refine strategy/logic.
#
# 2. **Tool Use Pattern**
#
#    * Agents leverage external tools or APIs to extend their capabilities.
#    * Useful for delegating specialized tasks that the agent cannot perform natively.
#
# 3. **Planning Pattern**
#
#    * Agents formulate and execute multi-step plans to achieve complex objectives.
#    * Plans are dynamically adapted based on goals and constraints.
#
# 4. **Multi-Agent Pattern**
#
#    * Multiple agents coordinate to solve complex tasks collaboratively.
#    * Useful when tasks require diverse skills or parallel execution.
#
#
# Additional resources: https://medium.com/@bijit211987/agentic-design-patterns-cbd0aae2962f

# %% [markdown]
# # Lesson 5: Agentic RAG vs. Basic RAG
# ## What is RAG?
# **RAG (Retrieval-Augmented Generation)** is a technique that enhances Large Language Models (LLMs) by allowing them to access external data sources.
# Instead of relying only on their training data, the model:
#
# 1. Receives a user query
# 2. Retrieves relevant information from a database or knowledge source
# 3. Injects that information into its context
# 4. Generates a more accurate and up-to-date response
#
# ## What is Agentic RAG?
# **Agentic RAG** extends basic RAG by introducing decision-making and iterative reasoning.
# Instead of performing a single retrieval step, an agent:
#
# 1. **Analyzes the query** and breaks it into smaller sub-tasks
# 2. **Selects tools and data sources** dynamically based on the task
# 3. **Retrieves and evaluates information**
# 4. **Checks whether the answer is sufficient**
# 5. **Repeats the process if needed** (iterative loop)
#
# This creates a more flexible and intelligent system that can handle complex queries.
#
# ### Key Advantages of Agentic RAG
#
# * **Multi-step reasoning** – breaks complex problems into manageable parts
# * **Tool usage** – can call different APIs, databases, or functions
# * **Self-evaluation** – verifies whether the retrieved information is sufficient
# * **Iterative improvement** – refines results through multiple passes
# * **Memory** – can retain past attempts and avoid repeating ineffective steps

# %% [markdown]
# # Lesson 6: How to Build Effective AI Agents
#
# ## The 5-Step Agent Loop
#
# There are 5 fundamental steps for building an AI agent:
#
# 1. **Get the Mission** — The process is initiated by a specific, high-level goal (given by a user or an automated trigger).
#
# 2. **Scan the Scene** — The agent perceives its environment to gather context. The orchestration layer accesses its available resources: *"What does the user's request say? What's in my short-term memory — did I already try this task, or did the user give me guidance last week? What can I access from my tools — calendars, databases, APIs?"*
#
# 3. **Think It Through** — The agent's core "think" loop, driven by the reasoning model. It analyzes the Mission (Step 1) against the Scene (Step 2) and devises a plan — a chain of reasoning: *"To book travel, I first need to know who is on the team. I'll use the `get_team_roster` tool. Then I'll check their availability via the `calendar_api`."*
#
# 4. **Take Action** — The orchestration layer executes the first concrete step of the plan, selecting and invoking the appropriate tool.
#
# 5. **Observe and Iterate** — The agent observes the outcome of its action. Say `get_team_roster` returns a list of five names — this new information is added to the agent's context ("memory"). The loop then returns to Step 3: *"Now that I have the roster, my next step is to check the calendar for these five people. I'll use the `calendar_api`."*
#
# This **Think, Act, Observe** cycle continues — managed by the Orchestration Layer, reasoned by the Model, and executed by the Tools — until the agent's internal plan is complete and the initial Mission is achieved.
#
# ## 1. System Message Framework
#
# * The **system message** provides the highest level of control over an AI agent.
# * Defines the agent's **behavior, goals, constraints, and tone**.
# * Ensures the agent performs the **intended actions consistently**.
#
# ### Framework Approach
#
# Instead of writing prompts manually:
#
# 1. Start with a **simple system message**.
# 2. Use an LLM with a **prompt template**.
# 3. Generate a **refined and improved system message**.
#
# This enables:
#
# * **Scalability** – reuse across multiple agents
# * **Consistency** – standardized behavior
# * **Iteration** – continuous improvement over time
#
# ## 2. Iterative Prompt Engineering
#
# * Prompt design is an **iterative process**.
# * Small improvements to the template lead to **better system messages across all agents**.
#
# The framework allows:
#
# * Easy **tweaking and experimentation**
# * Gradual **performance optimization**
# * More **reliable and predictable agent behavior**
#
# ## 3. Human-in-the-Loop Architecture
#
# * Keeps humans involved in **critical decision-making steps**.
# * Agents are instructed to wait for **specific user signals** before acting.
#
# ### Example
#
# * User says **"approve"** → agent proceeds with action.
# * No approval → agent **pauses, asks, or stops execution**.
#
# ### Why It Matters
#
# * **Safety** – prevents unintended or harmful actions
# * **Control** – user validates important steps
# * **Accountability** – decisions remain human-supervised
#
# ---
#
# **→ Effective agents are built through structured prompts, continuous iteration, and controlled execution with human oversight.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lesson 7: Planning Design Pattern
#
# ## 1. What is the Planning Design Pattern?
#
# * The **Planning design pattern** enables an AI agent to break down a complex task into smaller, manageable subtasks.
# * Instead of solving everything at once, the agent creates a **step-by-step plan**.
#
# ### Example
#
# * Task: Plan a 3-day vacation
#
#   * Flights
#   * Hotels
#   * Transportation
#   * Activities
#
# * Each subtask can be handled independently.
#
# ## 2. How Does It Help AI Agents Complete Tasks?
#
# * **Decomposition** – breaks complex problems into simpler parts
#
# * **Clarity** – defines a clear sequence of actions
#
# * **Efficiency** – reduces confusion and improves execution
#
# * **Error Handling** – easier to detect and fix issues in smaller steps
#
# * Helps agents move from:
#
#   * “Solve everything at once”
#     → to
#   * “Solve step-by-step with structure”
#
# ## 3. Using Planning with Multiple Agents
#
# * Planning becomes more powerful in **multi-agent systems**.
#
# * Each subtask can be:
#
#   * Assigned to a **different agent**
#   * Executed as a **separate process or tool call**
#
# ### Example Flow
#
# 1. Main agent creates a plan
# 2. Subtasks are distributed:
#
#    * Agent A → Flights
#    * Agent B → Hotels
#    * Agent C → Activities
# 3. Results are combined into a final output
#
# ## 4. How Can We Use It in Our Agents?
#
# * Add a **planning step before execution**
#
# * Store the plan as structured output (list of tasks)
#
# * Execute tasks:
#
#   * Sequentially (step-by-step)
#   * Or in parallel (multi-agent setup)
#
# * Optionally include:
#
#   * **Re-planning** if a step fails
#   * **Evaluation** after each step
#
# **→ Planning enables agents to solve complex problems by structuring them into clear, executable steps.**

# %% [markdown]
# # Lesson 8: How to Use a Multi-AI Agent System
#
# ## 1. What is a Multi-Agent System?
#
# * A **multi-agent system** consists of multiple AI agents working together to complete a task.
# * Each agent has a **specific role or specialization**.
#
# ### Core Components
#
# * **Group Chat**
#
#   * Messages are **broadcast to all agents**
#   * Enables shared context and communication
#
# * **Group Chat Manager**
#
#   * Typically another agent
#   * Selects the **appropriate agent to act next**
#   * Coordinates the workflow
#
# ## 2. Common Interaction Patterns
#
# ### Handoff Pattern
#
# * One agent transfers control to another agent when needed.
# * Used when a task requires **information or expertise from another agent**.
#
# ### Collaborative Filtering
#
# * Multiple agents contribute **different perspectives or analyses**.
#
# * Each agent acts as a **specialist** in a specific domain.
#
# * Useful for:
#
#   * Analysis tasks
#   * Decision-making
#   * Generating diverse outputs
#
#
# ## 3. Example of a Multi-Agent Workflow
#
# * Agent A → Generates content
#
# * Agent B → Evaluates and provides feedback
#
# * Workflow:
#
#   * **Generation → Evaluation → Improvement**
#
# ## 4. Multi-Agent vs. Single-Agent Systems
#
# ### Multi-Agent
#
# * **Pros:**
#
#   * Specialized agents → better performance per task
#   * Parallel execution → faster workflows
#   * Diverse perspectives → richer outputs
#
# * **Cons:**
#
#   * More complex coordination
#   * Higher resource usage
#   * Requires management (e.g., chat manager)
#
# ### Single-Agent
#
# * **Pros:**
#
#   * Simpler design
#   * Easier to manage and debug
#   * Lower overhead
#
# * **Cons:**
#
#   * Limited specialization
#   * Harder to scale for complex tasks
#
#
# ## 5. Control in Multi-Agent Systems
#
# * Control is achieved through:
#
#   * **Agent roles** – clear responsibilities
#   * **Manager agent** – directs task flow
#   * **Communication structure** – how agents share information
#
# * Important considerations:
#
#   * Avoid unnecessary loops or conflicts
#   * Ensure clear task ownership
#   * Maintain efficiency and coherence
#
# ## 6. Termination Conditions
#
# * **Termination functions** define when a multi-agent interaction should stop.
# * Prevents infinite loops and unnecessary computation.
#
# ### Why It Matters
#
# * **Efficiency** – avoids wasting resources
# * **Stability** – prevents endless back-and-forth between agents
# * **Clarity** – defines when a task is considered complete
#
# ### **Example: Writer–Checker System**
#
# * Agent A → Writes content
#
# * Agent B → Checks and evaluates
#
# * Workflow:
#
#   * Writer generates content
#   * Checker reviews
#   * If **not approved** → send feedback → Writer revises
#   * If **approved** → **terminate the conversation**
#
# ### **Common Termination Signals**
#
# * Explicit keyword (e.g., **"approved"**, **"done"**)
# * Confidence threshold reached
# * Maximum number of iterations
# * Task completion criteria met

# %% [markdown]
# # Lesson 9: Metacognition & Self-Improvement
#
# ## 1. What is Metacognition?
# Metacognition is often defined as **"thinking about thinking."** In the context of AI agents, it is the ability of a system to monitor, evaluate, and regulate its own reasoning process.
#
# * **Transparency:** It allows agents to be more explicit about *why* they made a specific choice.
# * **Adaptability:** It enables the agent to adjust its strategy if the environment or user requirements change mid-task.
#
# ## 2. The "Subjectivity" Challenge
# Metacognition is most powerful when dealing with subjective goals.
#
# * **The Flight Example:** If you ask an agent to book the "best" flight, "best" is a moving target (is it the cheapest? the fastest? the one with more legroom?).
# * **The Metacognitive Layer:** Enforce a step where the agent reflects on its definition of "best." It analyzes past interactions to see that you usually prioritize "no layovers" and adjusts its decision-making logic accordingly.
#
# ## 3. Improving Over Time
# For an agent to truly improve, we must design a system that can **Gather, Store, and Retrieve** feedback.
#
# * **The Feedback Loop:**
#     1. **Execute:** The agent performs a task.
#     2. **Evaluate:** The agent (or a human) assesses the outcome.
#     3. **Store:** The "lesson learned" is saved into Long-Term Memory.
#     4. **Retrieve:** The next time a similar task arises, the agent pulls that memory to avoid past mistakes.
#
# ## 4. Environmental Adaptation
# Environments are not static. A high-quality agent doesn't just fail when a tool breaks or a rule changes; it **adapts and explains.**
#
# * **The "Why" Factor:** If an agent changes its behavior (e.g., switching from Tool A to Tool B), a metacognitive agent can explain the logic: *"I noticed Tool A was timing out, so I pivoted to Tool B to ensure the task was completed on time."*
#
# **→ By embracing metacognition, we move from "Static Tools" to "Evolving Partners" that get smarter with every conversation.**

# %% [markdown]
# # Lesson 10: Deploying AI Agents Into Production
#
# ## 1. The Evaluation-First Mindset
# In production, you cannot just "vibe check" an agent. You need structured evaluation points at every stage of the workflow to ensure reliability.
#
# ### Key Evaluation Points:
# * **Intent Recognition:** Did the agent correctly interpret the user's goal? If the agent fails here, the rest of the chain is useless.
# * **Tool Selection Accuracy:** Did the agent pick the right tool for the job? (e.g., calling a `database_query` when it should have called a `web_search`).
# * **Tool Reliability:** How does the system handle tool errors, service timeouts, or malformed API responses?
# * **Latency & Response Time:** Agents are inherently slower than standard apps because of the "reasoning loops." Monitoring "Time to First Token" is critical for UX.
#
# ## 2. Feedback Loops & UI
# Evaluation doesn't end when the code is deployed; it continues through user interaction.
# * **Implicit Feedback:** Does the user ignore the response? Do they provide a follow-up correction?
# * **Explicit Feedback:** UI elements like 👍/👎 or "Was this helpful?" buttons.
# * **System Evolution:** Consistent evaluation allows you to swap models (e.g., moving from GPT-4 to a cheaper Llama-3) or update tools without breaking the core logic.
#
# ## 3. Common Mistakes in Production
# * **The "Infinite Loop":** An agent and a tool get stuck in an error loop, draining your API credits in minutes.
# * **Over-Engineering:** Using a Multi-Agent system for a task that a single prompt could have solved.
# * **Lack of Versioning:** Updating a tool's documentation without checking if the agent still understands how to use it.
# * **Hard-coding Prompts:** Not allowing for iterative updates to the system message without a full code redeploy.
#
# ## 4. Managing Costs
# Agents are "expensive" because they often make multiple LLM calls for a single user query.
#
# * **Token Budgeting:** Setting strict limits on the number of tokens an agent can consume per "turn."
# * **Model Routing:** Using a small, cheap model for "Intent Recognition" and only calling a large, expensive model for "Complex Reasoning."
# * **Caching:** Storing common tool responses or reasoning paths so the agent doesn't have to "re-think" the same problem twice.
#
# **→ Production-grade agents are defined by their reliability, not just their intelligence. If you can't measure it, you can't manage it.**

# %% [markdown]
# # Lesson 11: Agentic Protocols
#
# ## 1. MCP (Model Context Protocol)
# MCP acts as a **universal adapter** for LLM applications. It creates a standardized way for "Hosts" (the app) to connect to "Servers" (the tools/data).
#
# ### Why use MCP instead of standard APIs?
# * **Dynamic Tool Discovery:** The server provides a live list of capabilities. If the server adds a new feature, the agent sees it immediately—no code changes or manual documentation lookups required.
# * **Interoperability:** You can swap the underlying LLM (e.g., switching from Claude to GPT-4o) without rebuilding your data connectors.
# * **Standardized Security:** It provides a uniform authentication layer, making it safer and easier to manage permissions across multiple tools.
#
# ## 2. A2A (Agent-to-Agent)
# A2A allows independent agents to find, hire, and collaborate with one another across different platforms.
#
# * **The Agent Card:** A digital "business card" for AI. It contains a description of skills, specific tasks it can perform, and the endpoint URL for communication.
# * **The Agent Executor:** This allows a remote agent to join a task with full context. It’s like adding a specialist to a group chat and providing the conversation history so they can hit the ground running.
# * **The Artifact:** The final "package" sent by the remote agent. it includes the results of the work and a summary of what was done before the connection is closed.
#
# ## 3. NLWeb (Natural Language Web)
# NLWeb turns the internet into a giant, searchable interface for AI by creating a natural language layer over traditional websites.
#
# ### How it works:
# * **Websites as MCP Servers:** Through NLWeb, a site acts as a server where an agent can use an "Ask" method to pull specific info.
# * **Embedding Models:** The site’s content is converted into high-dimensional vectors (mathematical representations of meaning).
# * **Vector Databases:** These embeddings are stored in databases (like Elasticsearch or Azure AI Search), allowing agents to find the most relevant "answers" rather than just keyword matches.
# * **Structured Output:** Responses are returned in **JSON format**, ensuring the AI agent can parse the data reliably without "hallucinating" the layout.
